# %%
import numpy as np
import pandas as pd

# %%
weather=pd.read_csv(r"C:\Users\Lenovo\python-for-data-engineering-main\python-for-data-engineering-main\4. Python Advance\data\weather_2012.csv")

# %%
weather.shape
# Out:
# (8784, 8)

# %%
weather.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
weather.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
weather['Date/Time'].head()
# Out:
# 0    2012-01-01 00:00:00
# 1    2012-01-01 01:00:00
# 2    2012-01-01 02:00:00
# 3    2012-01-01 03:00:00
# 4    2012-01-01 04:00:00
# Name: Date/Time, dtype: object

# %%
weather['Date/Time']=pd.to_datetime(weather['Date/Time'])

# %%
weather['Date/Time'].head()
# Out:
# 0   2012-01-01 00:00:00
# 1   2012-01-01 01:00:00
# 2   2012-01-01 02:00:00
# 3   2012-01-01 03:00:00
# 4   2012-01-01 04:00:00
# Name: Date/Time, dtype: datetime64[ns]

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date/Time           8784 non-null   datetime64[ns]
#  1   Temp (C)            8784 non-null   float64
#  2   Dew Point Temp (C)  8784 non-null   float64
#  3   Rel Hum (%)         8784 non-null   int64
#  4   Wind Spd (km/h)     8784 non-null   int64
#  5   Visibility (km)     8784 non-null   float64
#  6   Stn Press (kPa)     8784 non-null   float64
#  7   Weather             8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %%
weather.head(10)
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
# 5 2012-01-01 05:00:00      -1.4                -3.3           87
# 6 2012-01-01 06:00:00      -1.5                -3.1           89
# 7 2012-01-01 07:00:00      -1.4                -3.6           85
# 8 2012-01-01 08:00:00      -1.4                -3.6           85
# 9 2012-01-01 09:00:00      -1.3                -3.1           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# ...

# %%
weather.tail(5)
# Out:
#                Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 8779 2012-12-31 19:00:00       0.1                -2.7           81
# 8780 2012-12-31 20:00:00       0.2                -2.4           83
# 8781 2012-12-31 21:00:00      -0.5                -1.5           93
# 8782 2012-12-31 22:00:00      -0.2                -1.8           89
# 8783 2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 8779               30              9.7           100.13    Snow
# 8780               24              9.7           100.03    Snow
# 8781               28              4.8            99.95    Snow
# 8782               28              9.7            99.91    Snow
# 8783               30             11.3            99.89    Snow

# %%
weather['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
weather['Wind Spd (km/h)'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
len(weather['Weather'].unique())
# Out:
# 50

# %%
weather['Wind Spd (km/h)'].nunique()
# Out:
# 34

# %%
weather['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
weather['Weather'].value_counts()[3]
# Out:
# 1326

# %%
weather['Wind Spd (km/h)'].value_counts()[9]
# Out:
# 830

# %%
col=weather['Weather']
print(type(col))
col.head()
# Out:
# <class 'pandas.core.series.Series'>
# 0                     Fog
# 1                     Fog
# 2    Freezing Drizzle,Fog
# 3    Freezing Drizzle,Fog
# 4                     Fog
# Name: Weather, dtype: object

# %%
col_2=weather[['Weather','Temp (C)']]
col_2.head()
# Out:
#                 Weather  Temp (C)
# 0                   Fog      -1.8
# 1                   Fog      -1.8
# 2  Freezing Drizzle,Fog      -1.8
# 3  Freezing Drizzle,Fog      -1.5
# 4                   Fog      -1.5

# %%
weather['Weather'][0:25:2]
# Out:
# 0                      Fog
# 2     Freezing Drizzle,Fog
# 4                      Fog
# 6                      Fog
# 8                      Fog
# 10                     Fog
# 12                     Fog
# 14                     Fog
# 16           Mostly Cloudy
# 18                    Rain
# 20                  Cloudy
# 22            Rain Showers
# 24            Rain Showers
# Name: Weather, dtype: object

# %%
weather['Temp (C)'].loc[0:5]
# Out:
# 0   -1.8
# 1   -1.8
# 2   -1.8
# 3   -1.5
# 4   -1.5
# 5   -1.4
# Name: Temp (C), dtype: float64

# %%
weather['Visibility (km)'].iloc[0:5]
# Out:
# 0    8.0
# 1    8.0
# 2    4.0
# 3    4.0
# 4    4.8
# Name: Visibility (km), dtype: float64

# %%
weather[['Visibility (km)','Rel Hum (%)']].loc[0:4:2]
# Out:
#    Visibility (km)  Rel Hum (%)
# 0              8.0           86
# 2              4.0           89
# 4              4.8           88

# %%
weather[['Visibility (km)','Rel Hum (%)']].iloc[0:5:2]
# Out:
#    Visibility (km)  Rel Hum (%)
# 0              8.0           86
# 2              4.0           89
# 4              4.8           88

# %%
weather['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
snow_filter=weather['Weather'].str.lower().str.contains('snow')

# %%
weather['Weather'].iloc[8782]
# Out:
# 'Snow'

# %%
weather[snow_filter]
# Out:
#                Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 41   2012-01-02 17:00:00      -2.1                -9.5           57
# 44   2012-01-02 20:00:00      -5.6               -13.4           54
# 45   2012-01-02 21:00:00      -5.8               -12.8           58
# 47   2012-01-02 23:00:00      -7.4               -14.1           59
# 48   2012-01-03 00:00:00      -9.0               -16.0           57
# ...                  ...       ...                 ...          ...
# 8779 2012-12-31 19:00:00       0.1                -2.7           81
# 8780 2012-12-31 20:00:00       0.2                -2.4           83
# 8781 2012-12-31 21:00:00      -0.5                -1.5           93
# 8782 2012-12-31 22:00:00      -0.2                -1.8           89
# 8783 2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)       Weather
# 41                 22             25.0            99.66  Snow Showers
# ...

# %%
filter_data=weather[(weather['Wind Spd (km/h)'] > 24) & (weather['Visibility (km)']==25)]

# %%
filter_data.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 23 2012-01-01 23:00:00       5.3                 2.0           79
# 24 2012-01-02 00:00:00       5.2                 1.5           77
# 25 2012-01-02 01:00:00       4.6                 0.0           72
# 26 2012-01-02 02:00:00       3.9                -0.9           71
# 27 2012-01-02 03:00:00       3.7                -1.5           69
#
#     Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# 23               30             25.0            99.31         Cloudy
# 24               35             25.0            99.26   Rain Showers
# 25               39             25.0            99.26         Cloudy
# 26               32             25.0            99.26  Mostly Cloudy
# 27               33             25.0            99.30  Mostly Cloudy

# %%
add=weather['Wind Spd (km/h)']+10
add.head()
# Out:
# 0    14
# 1    14
# 2    17
# 3    16
# 4    17
# Name: Wind Spd (km/h), dtype: int64

# %%
multi=weather['Visibility (km)']*2

# %%
multi.head()
# Out:
# 0    16.0
# 1    16.0
# 2     8.0
# 3     8.0
# 4     9.6
# Name: Visibility (km), dtype: float64

# %%
weather['Temp (C)'].head()
# Out:
# 0   -1.8
# 1   -1.8
# 2   -1.8
# 3   -1.5
# 4   -1.5
# Name: Temp (C), dtype: float64

# %%
weather['Dew Point Temp (C)'].head()
# Out:
# 0   -3.9
# 1   -3.7
# 2   -3.4
# 3   -3.2
# 4   -3.3
# Name: Dew Point Temp (C), dtype: float64

# %%
weather['temp+dew_temp']=weather['Temp (C)']+weather['Dew Point Temp (C)']

# %%
weather.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog
#
#    temp+dew_temp
# 0           -5.7
# 1           -5.5
# 2           -5.2
# 3           -4.7
# 4           -4.8

# %%
def times2(value):
    return value*2

# %%
time2=weather['Visibility (km)'].apply(times2)

# %%
weather['Visibility (km)'].head()
# Out:
# 0    8.0
# 1    8.0
# 2    4.0
# 3    4.0
# 4    4.8
# Name: Visibility (km), dtype: float64

# %%
time2.head()
# Out:
# 0    16.0
# 1    16.0
# 2     8.0
# 3     8.0
# 4     9.6
# Name: Visibility (km), dtype: float64

# %%
weather.describe()
# Out:
#           Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# count  8784.000000         8784.000000  8784.000000      8784.000000
# mean      8.798144            2.555294    67.431694        14.945469
# std      11.687883           10.883072    16.918881         8.688696
# min     -23.300000          -28.500000    18.000000         0.000000
# 25%       0.100000           -5.900000    56.000000         9.000000
# 50%       9.300000            3.300000    68.000000        13.000000
# 75%      18.800000           11.800000    81.000000        20.000000
# max      33.000000           24.400000   100.000000        83.000000
#
#        Visibility (km)  Stn Press (kPa)  temp+dew_temp
# count      8784.000000      8784.000000    8784.000000
# mean         27.664447       101.051623      11.353438
# std          12.622688         0.844005      22.188521
# min           0.200000        97.520000     -51.800000
# 25%          24.100000       100.560000      -5.300000
# ...

# %%
visibility_in_meter=weather['Visibility (km)']*1000

# %%
weather['Visibility (m)']=visibility_in_meter

# %%
weather.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                4           8000.0           101.24                   Fog
# 1                4           8000.0           101.24                   Fog
# 2                7           4000.0           101.26  Freezing Drizzle,Fog
# 3                6           4000.0           101.27  Freezing Drizzle,Fog
# 4                7           4800.0           101.23                   Fog
#
#    temp+dew_temp  Visibility (m)
# 0           -5.7          8000.0
# 1           -5.5          8000.0
# ...

# %%
weather.rename(columns={'Visibility (m)':'Visibility (meters)'},inplace=True)
weather.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                4           8000.0           101.24                   Fog
# 1                4           8000.0           101.24                   Fog
# 2                7           4000.0           101.26  Freezing Drizzle,Fog
# 3                6           4000.0           101.27  Freezing Drizzle,Fog
# 4                7           4800.0           101.23                   Fog
#
#    temp+dew_temp  Visibility (meters)
# 0           -5.7               8000.0
# 1           -5.5               8000.0
# ...

# %%
weather=weather.drop(labels=['Visibility (meters)'],axis=1)

# %%
weather.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                4           8000.0           101.24                   Fog
# 1                4           8000.0           101.24                   Fog
# 2                7           4000.0           101.26  Freezing Drizzle,Fog
# 3                6           4000.0           101.27  Freezing Drizzle,Fog
# 4                7           4800.0           101.23                   Fog
#
#    temp+dew_temp
# 0           -5.7
# 1           -5.5
# 2           -5.2
# 3           -4.7
# 4           -4.8

# %%
sorted_values=weather.sort_values('Temp (C)',ascending=False)

# %%
sorted_values.head()
# Out:
#                Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 4695 2012-07-14 15:00:00      33.0                16.8           38
# 4143 2012-06-21 15:00:00      33.0                19.0           44
# 4696 2012-07-14 16:00:00      32.9                15.3           35
# 5199 2012-08-04 15:00:00      32.8                18.8           44
# 4694 2012-07-14 14:00:00      32.7                15.3           35
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)       Weather  \
# 4695               22          48300.0           101.31  Mainly Clear
# 4143               24          24100.0           100.20  Mainly Clear
# 4696               24          48300.0           101.26  Mainly Clear
# 5199               17          24100.0           101.39         Clear
# 4694               28          48300.0           101.35  Mainly Clear
#
#       temp+dew_temp
# 4695           49.8
# 4143           52.0
# 4696           48.2
# 5199           51.6
# 4694           48.0

# %%
sorted_count=weather['Temp (C)'].value_counts().sort_values(ascending=False)

# %%
sorted_count.iloc[:10]
# Out:
# 16.6    65
# 1.1     58
# 0.8     47
# 1.5     45
# 19.3    44
# 21.1    43
# 2.6     43
# 0.4     41
# 1.3     40
# 14.6    39
# Name: Temp (C), dtype: int64

# %%
data = {
    'A': ['foo','foo','foo','bar','bar','bar'],
    'B': ['one','one','two','two','one','one'],
    'C': ['x','y','x','y','x','y'],
    'D': [1, 3, 2, 5, 4, 1]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
pivot_df=df.pivot_table(
                values='D',
                index='A',
                columns=['C'],
                aggfunc=np.sum)

# %%
pivot_df
# Out:
# C    x  y
# A
# bar  4  6
# foo  3  3

# %%
pivot_df.reset_index()
# Out:
# C    A  x  y
# 0  bar  4  6
# 1  foo  3  3

# %%
mean_temp_month_wise=weather.pivot_table(values='Temp (C)',index=weather['Date/Time'].dt.month,aggfunc=np.mean)

# %%
mean_temp_month_wise
# Out:
#             Temp (C)
# Date/Time
# 1          -7.371505
# 2          -4.225000
# 3           3.121237
# 4           7.009306
# 5          16.237769
# 6          20.134028
# 7          22.790054
# 8          22.279301
# 9          16.484444
# 10         10.954973
# 11          0.931389
# 12         -3.306317

# %%
mean_tmp_group_wise=weather.groupby(weather['Date/Time'].dt.month).agg(np.mean)['Temp (C)']

# %%
mean_tmp_group_wise.reset_index()
# Out:
#     Date/Time   Temp (C)
# 0           1  -7.371505
# 1           2  -4.225000
# 2           3   3.121237
# 3           4   7.009306
# 4           5  16.237769
# 5           6  20.134028
# 6           7  22.790054
# 7           8  22.279301
# 8           9  16.484444
# 9          10  10.954973
# 10         11   0.931389
# 11         12  -3.306317

# %%
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']
}, index=[0, 1, 2, 3])

df2 = pd.DataFrame({
    'A': ['A4', 'A5', 'A6', 'A7'],
    'B': ['B4', 'B5', 'B6', 'B7'],
    'C': ['C4', 'C5', 'C6', 'C7'],
    'D': ['D4', 'D5', 'D6', 'D7']
}, index=[4, 5, 6, 7])

df3 = pd.DataFrame({
    'A': ['A8', 'A9', 'A10', 'A11'],
    'B': ['B8', 'B9', 'B10', 'B11'],
    'C': ['C8', 'C9', 'C10', 'C11'],
    'E': ['D8', 'D9', 'D10', 'D11']
}, index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    E
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D    E
# 0    A0   B0   C0   D0  NaN
# 1    A1   B1   C1   D1  NaN
# 2    A2   B2   C2   D2  NaN
# 3    A3   B3   C3   D3  NaN
# 4    A4   B4   C4   D4  NaN
# 5    A5   B5   C5   D5  NaN
# 6    A6   B6   C6   D6  NaN
# 7    A7   B7   C7   D7  NaN
# 8    A8   B8   C8  NaN   D8
# 9    A9   B9   C9  NaN   D9
# 10  A10  B10  C10  NaN  D10
# 11  A11  B11  C11  NaN  D11

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    E
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
left_df = pd.DataFrame({
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2']
}, index=['K0', 'K1', 'K2']) 

right_df = pd.DataFrame({
    'C': ['C0', 'C2', 'C3'],
    'D': ['D0', 'D2', 'D3']
}, index=['K0', 'K2', 'K3'])

# %%
left_df
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right_df
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
left_df.join(right_df,how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
left_df.join(right_df,how='inner')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
left = pd.DataFrame({
    'key1': ['K0', 'K0', 'K1', 'K2'],
    'key2': ['K0', 'K1', 'K0', 'K1'],
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3']
})
    
right = pd.DataFrame({
    'key1': ['K0', 'K1', 'K1', 'K2'],
    'key2': ['K0', 'K0', 'K0', 'K0'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']
})

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left,right,how='left',on=['key1','key2'])
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN
